# %%
import numpy as np
import random
import copy

# %%
class Individual:
    
    def __init__(self, mentoriZauzetost, zeljeStudenata):
        self.mentoriZauzetost = copy.deepcopy(mentoriZauzetost)
        self.zeljeStudenata = copy.deepcopy(zeljeStudenata)
        self.brMentora = len(mentoriZauzetost)
        self.brStudenata = len(zeljeStudenata)
        self.maxBrojStudenata = sum(mentoriZauzetost)
        
        if self.maxBrojStudenata < self.brStudenata:
            print('Kapaciteti popunjeni! Nije moguce dodeliti mentora svakom studentu!')
        
        studenti = [i for i in range(0, self.brStudenata)]
        random.shuffle(studenti)
        mentori = []
        br=0
        for i in range(self.brMentora):
            for j in range(self.mentoriZauzetost[i]):
                if br + j > self.brStudenata:
                    break
                else :
                    mentori.append(i)
            br += j
        self.code = []
        for i in range(self.brStudenata):
            self.code.append((studenti[i], mentori[i]))
        self.fitness = self.fitnessFunction()
        
    def fitnessFunction(self):
        val = 0
        for i in range(self.brStudenata):
            val += self.geneFitness(i)
        return val
    
    def geneFitness(self, i):
        (student, mentor) = self.code[i]
        return self.zeljeStudenata[student][mentor]
    
    def __lt__(self, other):
        return self.fitness < other.fitness

# %%
def mutation(individual, mutation_rate):
    
    if random.uniform(0,1) < mutation_rate:
        i = random.randrange(individual.brStudenata)
        j = random.randrange(individual.brStudenata)
        tmp = individual.code[i][0]
        individual.code[i] = (individual.code[j][0], individual.code[i][1])
        individual.code[j] = (tmp, individual.code[j][1])

# %%
def selection(population, tournament_size):
    val = float('inf')
    bestInd = -1
    for _ in range(tournament_size):
        i = random.randrange(len(population))
        if population[i].fitness < val:
            val = population[i].fitness
            bestInd = i
    return bestInd

# %%
def crossover(parent1, parent2, child1, child2):
    
    n = parent1.brStudenata
    dodeljeni1 = set()
    dodeljeni2 = set()
    nisuDodeljenji1 = set()
    nisuDodeljenji2 = set()
    for i in range(n):
        nisuDodeljenji1.add(parent1.code[i][0])
        nisuDodeljenji2.add(parent1.code[i][0])
    for i in range(n):
        child1.code[i] = (-1, child1.code[i][1])
        child2.code[i] = (-1, child2.code[i][1])
    for i in range(n):
        if parent1.geneFitness(i) < parent2.geneFitness(i) and parent1.code[i][0] not in dodeljeni1 and parent1.code[i][0] in nisuDodeljenji1:
            child1.code[i] = (parent1.code[i][0], child1.code[i][1])
            dodeljeni1.add(child1.code[i][0])
            nisuDodeljenji1.remove(child1.code[i][0])
        elif parent1.geneFitness(i) > parent2.geneFitness(i) and parent2.code[i][0] not in dodeljeni1 and parent2.code[i][0] in nisuDodeljenji1:
            child1.code[i] = (parent2.code[i][0], child1.code[i][1])
            dodeljeni1.add(child1.code[i][0])
            nisuDodeljenji1.remove(child1.code[i][0])
    
    k=n-1
    while k>=0:
        if parent1.geneFitness(k) < parent2.geneFitness(k) and parent1.code[k][0] not in dodeljeni2 and parent1.code[k][0] in nisuDodeljenji2:
            child2.code[k] = (parent1.code[k][0], child2.code[k][1])
            dodeljeni2.add(child2.code[k][0])
            nisuDodeljenji2.remove(child2.code[k][0])
        elif parent1.geneFitness(k) > parent2.geneFitness(k) and parent2.code[k][0] not in dodeljeni2 and parent2.code[k][0] in nisuDodeljenji2:
            child2.code[k] = (parent2.code[k][0], child2.code[k][1])
            dodeljeni2.add(child2.code[k][0])
            nisuDodeljenji2.remove(child2.code[k][0])
        k-=1
    
    for i in range(n):
        if child1.code[i][0] == -1:
           
            child1.code[i] = (random.sample(nisuDodeljenji1, 1)[0], child1.code[i][1])
            
            nisuDodeljenji1.remove(child1.code[i][0])
        if child2.code[i][0] == -1:
           
            child2.code[i] = (random.sample(nisuDodeljenji2, 1)[0], child2.code[i][1])
            
            nisuDodeljenji2.remove(child2.code[i][0])
            
    child1.fitness = child1.fitnessFunction()
    child2.fitness = child2.fitnessFunction()
    
    if child1.fitness > parent1.fitness:
        child1 = parent1
    if child1.fitness > parent2.fitness:
        child1 = parent2
    if child2.fitness > parent1.fitness:
        child2 = parent1
    if child2.fitness > parent2.fitness:
        child2 = parent2

# %%
mentoriZauzetost = [random.randint(3,8) for i in range(10)]
zeljeStudenata = [[int(i) for i in range(10)] for j in range(50)]

for i in range(len(zeljeStudenata)):
    random.shuffle(zeljeStudenata[i])
    
print(len(zeljeStudenata), len(zeljeStudenata[0]))
# Out:
# 50 10

# %%
population_size = 100
mutation_rate = 0.1
tournament_size = 6
max_iter = 1000
elitism_size = 20
population = [Individual(mentoriZauzetost, zeljeStudenata) for _ in range(population_size)]
new_population = [Individual(mentoriZauzetost, zeljeStudenata) for _ in range(population_size)]
# for i in range(population_size):
#     print(population[i].code)

for iteration in range(max_iter):
    population.sort()
    
    
    print(iteration,'-ta iteracija, najbolji fitness je: ', population[0].fitness)
    if population[0].fitness == 0:
        print("Svakom studentu je ispunjena prva zelja!")
        break
    for i in range(elitism_size):
        new_population[i] = population[i]
    for i in range(elitism_size, population_size, 2):
        p1 = selection(population, tournament_size)
        p2 = selection(population, tournament_size)
        
        crossover(population[p1], population[p2], new_population[i], new_population[i+1])
        
        mutation(new_population[i], mutation_rate)
        mutation(new_population[i+1], mutation_rate)
        new_population[i].fitness = new_population[i].fitnessFunction()
        new_population[i+1].fitness = new_population[i+1].fitnessFunction()
        
    population = new_population

population.sort()

print("najbolje resenje je:")
print(population[0].code)
print(population[0].fitness)
# Out:
# 0 -ta iteracija, najbolji fitness je:  176
# 1 -ta iteracija, najbolji fitness je:  115
# 2 -ta iteracija, najbolji fitness je:  74
# 3 -ta iteracija, najbolji fitness je:  74
# 4 -ta iteracija, najbolji fitness je:  74
# 5 -ta iteracija, najbolji fitness je:  74
# 6 -ta iteracija, najbolji fitness je:  74
# 7 -ta iteracija, najbolji fitness je:  74
# 8 -ta iteracija, najbolji fitness je:  66
# 9 -ta iteracija, najbolji fitness je:  66
# 10 -ta iteracija, najbolji fitness je:  66
# 11 -ta iteracija, najbolji fitness je:  66
# 12 -ta iteracija, najbolji fitness je:  66
# 13 -ta iteracija, najbolji fitness je:  66
# 14 -ta iteracija, najbolji fitness je:  66
# 15 -ta iteracija, najbolji fitness je:  66
# 16 -ta iteracija, najbolji fitness je:  66
# 17 -ta iteracija, najbolji fitness je:  66
# 18 -ta iteracija, najbolji fitness je:  66
# 19 -ta iteracija, najbolji fitness je:  66
# 20 -ta iteracija, najbolji fitness je:  66
# 21 -ta iteracija, najbolji fitness je:  61
# 22 -ta iteracija, najbolji fitness je:  61
# 23 -ta iteracija, najbolji fitness je:  61
# 24 -ta iteracija, najbolji fitness je:  61
# 25 -ta iteracija, najbolji fitness je:  61
# 26 -ta iteracija, najbolji fitness je:  61
# 27 -ta iteracija, najbolji fitness je:  61
# 28 -ta iteracija, najbolji fitness je:  61
# 29 -ta iteracija, najbolji fitness je:  61
# 30 -ta iteracija, najbolji fitness je:  61
# 31 -ta iteracija, najbolji fitness je:  57
# 32 -ta iteracija, najbolji fitness je:  57
# 33 -ta iteracija, najbolji fitness je:  57
# 34 -ta iteracija, najbolji fitness je:  57
# 35 -ta iteracija, najbolji fitness je:  57
# 36 -ta iteracija, najbolji fitness je:  57
# 37 -ta iteracija, najbolji fitness je:  57
# 38 -ta iteracija, najbolji fitness je:  57
# 39 -ta iteracija, najbolji fitness je:  57
# 40 -ta iteracija, najbolji fitness je:  57
# 41 -ta iteracija, najbolji fitness je:  57
# 42 -ta iteracija, najbolji fitness je:  57
# 43 -ta iteracija, najbolji fitness je:  57
# 44 -ta iteracija, najbolji fitness je:  57
# 45 -ta iteracija, najbolji fitness je:  57
# 46 -ta iteracija, najbolji fitness je:  57
# 47 -ta iteracija, najbolji fitness je:  57
# 48 -ta iteracija, najbolji fitness je:  57
# 49 -ta iteracija, najbolji fitness je:  57
# 50 -ta iteracija, najbolji fitness je:  57
# 51 -ta iteracija, najbolji fitness je:  57
# 52 -ta iteracija, najbolji fitness je:  57
# 53 -ta iteracija, najbolji fitness je:  57
# 54 -ta iteracija, najbolji fitness je:  55
# 55 -ta iteracija, najbolji fitness je:  55
# 56 -ta iteracija, najbolji fitness je:  55
# 57 -ta iteracija, najbolji fitness je:  55
# 58 -ta iteracija, najbolji fitness je:  55
# 59 -ta iteracija, najbolji fitness je:  55
# 60 -ta iteracija, najbolji fitness je:  55
# 61 -ta iteracija, najbolji fitness je:  55
# 62 -ta iteracija, najbolji fitness je:  55
# 63 -ta iteracija, najbolji fitness je:  55
# 64 -ta iteracija, najbolji fitness je:  55
# 65 -ta iteracija, najbolji fitness je:  55
# 66 -ta iteracija, najbolji fitness je:  55
# 67 -ta iteracija, najbolji fitness je:  50
# 68 -ta iteracija, najbolji fitness je:  50
# 69 -ta iteracija, najbolji fitness je:  50
# 70 -ta iteracija, najbolji fitness je:  50
# 71 -ta iteracija, najbolji fitness je:  50
# 72 -ta iteracija, najbolji fitness je:  50
# 73 -ta iteracija, najbolji fitness je:  50
# 74 -ta iteracija, najbolji fitness je:  50
# 75 -ta iteracija, najbolji fitness je:  50
# 76 -ta iteracija, najbolji fitness je:  50
# 77 -ta iteracija, najbolji fitness je:  50
# 78 -ta iteracija, najbolji fitness je:  50
# 79 -ta iteracija, najbolji fitness je:  50
# 80 -ta iteracija, najbolji fitness je:  50
# 81 -ta iteracija, najbolji fitness je:  50
# 82 -ta iteracija, najbolji fitness je:  50
# 83 -ta iteracija, najbolji fitness je:  44
# 84 -ta iteracija, najbolji fitness je:  44
# 85 -ta iteracija, najbolji fitness je:  44
# 86 -ta iteracija, najbolji fitness je:  44
# 87 -ta iteracija, najbolji fitness je:  44
# 88 -ta iteracija, najbolji fitness je:  44
# 89 -ta iteracija, najbolji fitness je:  44
# 90 -ta iteracija, najbolji fitness je:  44
# 91 -ta iteracija, najbolji fitness je:  44
# 92 -ta iteracija, najbolji fitness je:  44
# 93 -ta iteracija, najbolji fitness je:  44
# 94 -ta iteracija, najbolji fitness je:  44
# 95 -ta iteracija, najbolji fitness je:  44
# 96 -ta iteracija, najbolji fitness je:  44
# 97 -ta iteracija, najbolji fitness je:  44
# 98 -ta iteracija, najbolji fitness je:  44
# 99 -ta iteracija, najbolji fitness je:  44
# 100 -ta iteracija, najbolji fitness je:  44
# 101 -ta iteracija, najbolji fitness je:  44
# 102 -ta iteracija, najbolji fitness je:  44
# 103 -ta iteracija, najbolji fitness je:  44
# 104 -ta iteracija, najbolji fitness je:  44
# 105 -ta iteracija, najbolji fitness je:  44
# 106 -ta iteracija, najbolji fitness je:  44
# 107 -ta iteracija, najbolji fitness je:  44
# 108 -ta iteracija, najbolji fitness je:  44
# 109 -ta iteracija, najbolji fitness je:  44
# 110 -ta iteracija, najbolji fitness je:  44
# 111 -ta iteracija, najbolji fitness je:  44
# 112 -ta iteracija, najbolji fitness je:  44
# 113 -ta iteracija, najbolji fitness je:  44
# 114 -ta iteracija, najbolji fitness je:  44
# 115 -ta iteracija, najbolji fitness je:  44
# 116 -ta iteracija, najbolji fitness je:  44
# 117 -ta iteracija, najbolji fitness je:  44
# 118 -ta iteracija, najbolji fitness je:  44
# 119 -ta iteracija, najbolji fitness je:  44
# 120 -ta iteracija, najbolji fitness je:  44
# 121 -ta iteracija, najbolji fitness je:  44
# 122 -ta iteracija, najbolji fitness je:  44
# 123 -ta iteracija, najbolji fitness je:  44
# 124 -ta iteracija, najbolji fitness je:  44
# 125 -ta iteracija, najbolji fitness je:  44
# 126 -ta iteracija, najbolji fitness je:  44
# 127 -ta iteracija, najbolji fitness je:  44
# 128 -ta iteracija, najbolji fitness je:  44
# 129 -ta iteracija, najbolji fitness je:  44
# 130 -ta iteracija, najbolji fitness je:  44
# 131 -ta iteracija, najbolji fitness je:  44
# 132 -ta iteracija, najbolji fitness je:  44
# 133 -ta iteracija, najbolji fitness je:  44
# 134 -ta iteracija, najbolji fitness je:  44
# 135 -ta iteracija, najbolji fitness je:  44
# 136 -ta iteracija, najbolji fitness je:  44
# 137 -ta iteracija, najbolji fitness je:  44
# 138 -ta iteracija, najbolji fitness je:  44
# 139 -ta iteracija, najbolji fitness je:  44
# 140 -ta iteracija, najbolji fitness je:  44
# 141 -ta iteracija, najbolji fitness je:  44
# 142 -ta iteracija, najbolji fitness je:  44
# 143 -ta iteracija, najbolji fitness je:  44
# 144 -ta iteracija, najbolji fitness je:  44
# 145 -ta iteracija, najbolji fitness je:  44
# 146 -ta iteracija, najbolji fitness je:  44
# 147 -ta iteracija, najbolji fitness je:  44
# 148 -ta iteracija, najbolji fitness je:  44
# 149 -ta iteracija, najbolji fitness je:  44
# 150 -ta iteracija, najbolji fitness je:  44
# 151 -ta iteracija, najbolji fitness je:  44
# 152 -ta iteracija, najbolji fitness je:  44
# 153 -ta iteracija, najbolji fitness je:  44
# 154 -ta iteracija, najbolji fitness je:  44
# 155 -ta iteracija, najbolji fitness je:  44
# 156 -ta iteracija, najbolji fitness je:  44
# 157 -ta iteracija, najbolji fitness je:  44
# 158 -ta iteracija, najbolji fitness je:  44
# 159 -ta iteracija, najbolji fitness je:  44
# 160 -ta iteracija, najbolji fitness je:  44
# 161 -ta iteracija, najbolji fitness je:  44
# 162 -ta iteracija, najbolji fitness je:  44
# 163 -ta iteracija, najbolji fitness je:  44
# 164 -ta iteracija, najbolji fitness je:  44
# 165 -ta iteracija, najbolji fitness je:  44
# 166 -ta iteracija, najbolji fitness je:  44
# 167 -ta iteracija, najbolji fitness je:  44
# 168 -ta iteracija, najbolji fitness je:  44
# 169 -ta iteracija, najbolji fitness je:  44
# 170 -ta iteracija, najbolji fitness je:  44
# 171 -ta iteracija, najbolji fitness je:  44
# 172 -ta iteracija, najbolji fitness je:  44
# 173 -ta iteracija, najbolji fitness je:  44
# 174 -ta iteracija, najbolji fitness je:  44
# 175 -ta iteracija, najbolji fitness je:  44
# 176 -ta iteracija, najbolji fitness je:  44
# 177 -ta iteracija, najbolji fitness je:  44
# 178 -ta iteracija, najbolji fitness je:  44
# 179 -ta iteracija, najbolji fitness je:  44
# 180 -ta iteracija, najbolji fitness je:  44
# 181 -ta iteracija, najbolji fitness je:  44
# 182 -ta iteracija, najbolji fitness je:  44
# 183 -ta iteracija, najbolji fitness je:  44
# 184 -ta iteracija, najbolji fitness je:  44
# 185 -ta iteracija, najbolji fitness je:  44
# 186 -ta iteracija, najbolji fitness je:  44
# 187 -ta iteracija, najbolji fitness je:  44
# 188 -ta iteracija, najbolji fitness je:  44
# 189 -ta iteracija, najbolji fitness je:  44
# 190 -ta iteracija, najbolji fitness je:  44
# 191 -ta iteracija, najbolji fitness je:  44
# 192 -ta iteracija, najbolji fitness je:  44
# 193 -ta iteracija, najbolji fitness je:  44
# 194 -ta iteracija, najbolji fitness je:  44
# 195 -ta iteracija, najbolji fitness je:  44
# 196 -ta iteracija, najbolji fitness je:  44
# 197 -ta iteracija, najbolji fitness je:  44
# 198 -ta iteracija, najbolji fitness je:  44
# 199 -ta iteracija, najbolji fitness je:  44
# 200 -ta iteracija, najbolji fitness je:  44
# 201 -ta iteracija, najbolji fitness je:  43
# 202 -ta iteracija, najbolji fitness je:  43
# 203 -ta iteracija, najbolji fitness je:  43
# 204 -ta iteracija, najbolji fitness je:  43
# 205 -ta iteracija, najbolji fitness je:  43
# 206 -ta iteracija, najbolji fitness je:  43
# 207 -ta iteracija, najbolji fitness je:  43
# 208 -ta iteracija, najbolji fitness je:  43
# 209 -ta iteracija, najbolji fitness je:  43
# 210 -ta iteracija, najbolji fitness je:  43
# 211 -ta iteracija, najbolji fitness je:  43
# 212 -ta iteracija, najbolji fitness je:  43
# 213 -ta iteracija, najbolji fitness je:  43
# 214 -ta iteracija, najbolji fitness je:  43
# 215 -ta iteracija, najbolji fitness je:  43
# 216 -ta iteracija, najbolji fitness je:  43
# 217 -ta iteracija, najbolji fitness je:  43
# 218 -ta iteracija, najbolji fitness je:  43
# 219 -ta iteracija, najbolji fitness je:  43
# 220 -ta iteracija, najbolji fitness je:  43
# 221 -ta iteracija, najbolji fitness je:  43
# 222 -ta iteracija, najbolji fitness je:  43
# 223 -ta iteracija, najbolji fitness je:  43
# 224 -ta iteracija, najbolji fitness je:  43
# 225 -ta iteracija, najbolji fitness je:  43
# 226 -ta iteracija, najbolji fitness je:  43
# 227 -ta iteracija, najbolji fitness je:  43
# 228 -ta iteracija, najbolji fitness je:  43
# 229 -ta iteracija, najbolji fitness je:  43
# 230 -ta iteracija, najbolji fitness je:  43
# 231 -ta iteracija, najbolji fitness je:  43
# 232 -ta iteracija, najbolji fitness je:  43
# 233 -ta iteracija, najbolji fitness je:  43
# 234 -ta iteracija, najbolji fitness je:  43
# 235 -ta iteracija, najbolji fitness je:  43
# 236 -ta iteracija, najbolji fitness je:  43
# 237 -ta iteracija, najbolji fitness je:  43
# 238 -ta iteracija, najbolji fitness je:  43
# 239 -ta iteracija, najbolji fitness je:  43
# 240 -ta iteracija, najbolji fitness je:  43
# 241 -ta iteracija, najbolji fitness je:  43
# 242 -ta iteracija, najbolji fitness je:  43
# 243 -ta iteracija, najbolji fitness je:  43
# 244 -ta iteracija, najbolji fitness je:  43
# 245 -ta iteracija, najbolji fitness je:  43
# 246 -ta iteracija, najbolji fitness je:  43
# 247 -ta iteracija, najbolji fitness je:  43
# 248 -ta iteracija, najbolji fitness je:  43
# 249 -ta iteracija, najbolji fitness je:  43
# 250 -ta iteracija, najbolji fitness je:  43
# 251 -ta iteracija, najbolji fitness je:  43
# 252 -ta iteracija, najbolji fitness je:  43
# 253 -ta iteracija, najbolji fitness je:  43
# 254 -ta iteracija, najbolji fitness je:  43
# 255 -ta iteracija, najbolji fitness je:  43
# 256 -ta iteracija, najbolji fitness je:  43
# 257 -ta iteracija, najbolji fitness je:  43
# 258 -ta iteracija, najbolji fitness je:  43
# 259 -ta iteracija, najbolji fitness je:  43
# 260 -ta iteracija, najbolji fitness je:  43
# 261 -ta iteracija, najbolji fitness je:  43
# 262 -ta iteracija, najbolji fitness je:  43
# 263 -ta iteracija, najbolji fitness je:  43
# 264 -ta iteracija, najbolji fitness je:  43
# 265 -ta iteracija, najbolji fitness je:  43
# 266 -ta iteracija, najbolji fitness je:  43
# 267 -ta iteracija, najbolji fitness je:  43
# 268 -ta iteracija, najbolji fitness je:  43
# 269 -ta iteracija, najbolji fitness je:  43
# 270 -ta iteracija, najbolji fitness je:  43
# 271 -ta iteracija, najbolji fitness je:  43
# 272 -ta iteracija, najbolji fitness je:  43
# 273 -ta iteracija, najbolji fitness je:  43
# 274 -ta iteracija, najbolji fitness je:  43
# 275 -ta iteracija, najbolji fitness je:  43
# 276 -ta iteracija, najbolji fitness je:  43
# 277 -ta iteracija, najbolji fitness je:  43
# 278 -ta iteracija, najbolji fitness je:  43
# 279 -ta iteracija, najbolji fitness je:  43
# 280 -ta iteracija, najbolji fitness je:  43
# 281 -ta iteracija, najbolji fitness je:  43
# 282 -ta iteracija, najbolji fitness je:  43
# 283 -ta iteracija, najbolji fitness je:  43
# 284 -ta iteracija, najbolji fitness je:  43
# 285 -ta iteracija, najbolji fitness je:  43
# 286 -ta iteracija, najbolji fitness je:  43
# 287 -ta iteracija, najbolji fitness je:  43
# 288 -ta iteracija, najbolji fitness je:  43
# 289 -ta iteracija, najbolji fitness je:  43
# 290 -ta iteracija, najbolji fitness je:  43
# 291 -ta iteracija, najbolji fitness je:  43
# 292 -ta iteracija, najbolji fitness je:  43
# 293 -ta iteracija, najbolji fitness je:  43
# 294 -ta iteracija, najbolji fitness je:  43
# 295 -ta iteracija, najbolji fitness je:  43
# 296 -ta iteracija, najbolji fitness je:  43
# 297 -ta iteracija, najbolji fitness je:  43
# 298 -ta iteracija, najbolji fitness je:  43
# 299 -ta iteracija, najbolji fitness je:  43
# 300 -ta iteracija, najbolji fitness je:  43
# 301 -ta iteracija, najbolji fitness je:  43
# 302 -ta iteracija, najbolji fitness je:  43
# 303 -ta iteracija, najbolji fitness je:  43
# 304 -ta iteracija, najbolji fitness je:  43
# 305 -ta iteracija, najbolji fitness je:  43
# 306 -ta iteracija, najbolji fitness je:  43
# 307 -ta iteracija, najbolji fitness je:  43
# 308 -ta iteracija, najbolji fitness je:  43
# 309 -ta iteracija, najbolji fitness je:  43
# 310 -ta iteracija, najbolji fitness je:  43
# 311 -ta iteracija, najbolji fitness je:  43
# 312 -ta iteracija, najbolji fitness je:  43
# 313 -ta iteracija, najbolji fitness je:  43
# 314 -ta iteracija, najbolji fitness je:  40
# 315 -ta iteracija, najbolji fitness je:  40
# 316 -ta iteracija, najbolji fitness je:  40
# 317 -ta iteracija, najbolji fitness je:  40
# 318 -ta iteracija, najbolji fitness je:  40
# 319 -ta iteracija, najbolji fitness je:  40
# 320 -ta iteracija, najbolji fitness je:  40
# 321 -ta iteracija, najbolji fitness je:  40
# 322 -ta iteracija, najbolji fitness je:  40
# 323 -ta iteracija, najbolji fitness je:  40
# 324 -ta iteracija, najbolji fitness je:  40
# 325 -ta iteracija, najbolji fitness je:  40
# 326 -ta iteracija, najbolji fitness je:  40
# 327 -ta iteracija, najbolji fitness je:  40
# 328 -ta iteracija, najbolji fitness je:  40
# 329 -ta iteracija, najbolji fitness je:  40
# 330 -ta iteracija, najbolji fitness je:  40
# 331 -ta iteracija, najbolji fitness je:  40
# 332 -ta iteracija, najbolji fitness je:  40
# 333 -ta iteracija, najbolji fitness je:  40
# 334 -ta iteracija, najbolji fitness je:  40
# 335 -ta iteracija, najbolji fitness je:  40
# 336 -ta iteracija, najbolji fitness je:  40
# 337 -ta iteracija, najbolji fitness je:  40
# 338 -ta iteracija, najbolji fitness je:  40
# 339 -ta iteracija, najbolji fitness je:  40
# 340 -ta iteracija, najbolji fitness je:  40
# 341 -ta iteracija, najbolji fitness je:  40
# 342 -ta iteracija, najbolji fitness je:  40
# 343 -ta iteracija, najbolji fitness je:  40
# 344 -ta iteracija, najbolji fitness je:  40
# 345 -ta iteracija, najbolji fitness je:  40
# 346 -ta iteracija, najbolji fitness je:  40
# 347 -ta iteracija, najbolji fitness je:  40
# 348 -ta iteracija, najbolji fitness je:  40
# 349 -ta iteracija, najbolji fitness je:  40
# 350 -ta iteracija, najbolji fitness je:  40
# 351 -ta iteracija, najbolji fitness je:  40
# 352 -ta iteracija, najbolji fitness je:  40
# 353 -ta iteracija, najbolji fitness je:  40
# 354 -ta iteracija, najbolji fitness je:  40
# 355 -ta iteracija, najbolji fitness je:  40
# 356 -ta iteracija, najbolji fitness je:  40
# 357 -ta iteracija, najbolji fitness je:  40
# 358 -ta iteracija, najbolji fitness je:  40
# 359 -ta iteracija, najbolji fitness je:  40
# 360 -ta iteracija, najbolji fitness je:  40
# 361 -ta iteracija, najbolji fitness je:  40
# 362 -ta iteracija, najbolji fitness je:  40
# 363 -ta iteracija, najbolji fitness je:  40
# 364 -ta iteracija, najbolji fitness je:  40
# 365 -ta iteracija, najbolji fitness je:  40
# 366 -ta iteracija, najbolji fitness je:  37
# 367 -ta iteracija, najbolji fitness je:  37
# 368 -ta iteracija, najbolji fitness je:  37
# 369 -ta iteracija, najbolji fitness je:  37
# 370 -ta iteracija, najbolji fitness je:  37
# 371 -ta iteracija, najbolji fitness je:  37
# 372 -ta iteracija, najbolji fitness je:  37
# 373 -ta iteracija, najbolji fitness je:  37
# 374 -ta iteracija, najbolji fitness je:  37
# 375 -ta iteracija, najbolji fitness je:  37
# 376 -ta iteracija, najbolji fitness je:  37
# 377 -ta iteracija, najbolji fitness je:  37
# 378 -ta iteracija, najbolji fitness je:  37
# 379 -ta iteracija, najbolji fitness je:  37
# 380 -ta iteracija, najbolji fitness je:  37
# 381 -ta iteracija, najbolji fitness je:  37
# 382 -ta iteracija, najbolji fitness je:  37
# 383 -ta iteracija, najbolji fitness je:  37
# 384 -ta iteracija, najbolji fitness je:  37
# 385 -ta iteracija, najbolji fitness je:  37
# 386 -ta iteracija, najbolji fitness je:  37
# 387 -ta iteracija, najbolji fitness je:  37
# 388 -ta iteracija, najbolji fitness je:  37
# 389 -ta iteracija, najbolji fitness je:  37
# 390 -ta iteracija, najbolji fitness je:  37
# 391 -ta iteracija, najbolji fitness je:  37
# 392 -ta iteracija, najbolji fitness je:  37
# 393 -ta iteracija, najbolji fitness je:  37
# 394 -ta iteracija, najbolji fitness je:  37
# 395 -ta iteracija, najbolji fitness je:  37
# 396 -ta iteracija, najbolji fitness je:  37
# 397 -ta iteracija, najbolji fitness je:  37
# 398 -ta iteracija, najbolji fitness je:  37
# 399 -ta iteracija, najbolji fitness je:  37
# 400 -ta iteracija, najbolji fitness je:  37
# 401 -ta iteracija, najbolji fitness je:  37
# 402 -ta iteracija, najbolji fitness je:  37
# 403 -ta iteracija, najbolji fitness je:  37
# 404 -ta iteracija, najbolji fitness je:  37
# 405 -ta iteracija, najbolji fitness je:  37
# 406 -ta iteracija, najbolji fitness je:  37
# 407 -ta iteracija, najbolji fitness je:  37
# 408 -ta iteracija, najbolji fitness je:  37
# 409 -ta iteracija, najbolji fitness je:  37
# 410 -ta iteracija, najbolji fitness je:  37
# 411 -ta iteracija, najbolji fitness je:  37
# 412 -ta iteracija, najbolji fitness je:  37
# 413 -ta iteracija, najbolji fitness je:  37
# 414 -ta iteracija, najbolji fitness je:  37
# 415 -ta iteracija, najbolji fitness je:  37
# 416 -ta iteracija, najbolji fitness je:  37
# 417 -ta iteracija, najbolji fitness je:  37
# 418 -ta iteracija, najbolji fitness je:  37
# 419 -ta iteracija, najbolji fitness je:  37
# 420 -ta iteracija, najbolji fitness je:  37
# 421 -ta iteracija, najbolji fitness je:  37
# 422 -ta iteracija, najbolji fitness je:  37
# 423 -ta iteracija, najbolji fitness je:  37
# 424 -ta iteracija, najbolji fitness je:  37
# 425 -ta iteracija, najbolji fitness je:  37
# 426 -ta iteracija, najbolji fitness je:  37
# 427 -ta iteracija, najbolji fitness je:  37
# 428 -ta iteracija, najbolji fitness je:  37
# 429 -ta iteracija, najbolji fitness je:  37
# 430 -ta iteracija, najbolji fitness je:  37
# 431 -ta iteracija, najbolji fitness je:  37
# 432 -ta iteracija, najbolji fitness je:  37
# 433 -ta iteracija, najbolji fitness je:  37
# 434 -ta iteracija, najbolji fitness je:  37
# 435 -ta iteracija, najbolji fitness je:  37
# 436 -ta iteracija, najbolji fitness je:  37
# 437 -ta iteracija, najbolji fitness je:  37
# 438 -ta iteracija, najbolji fitness je:  37
# 439 -ta iteracija, najbolji fitness je:  37
# 440 -ta iteracija, najbolji fitness je:  37
# 441 -ta iteracija, najbolji fitness je:  37
# 442 -ta iteracija, najbolji fitness je:  37
# 443 -ta iteracija, najbolji fitness je:  37
# 444 -ta iteracija, najbolji fitness je:  37
# 445 -ta iteracija, najbolji fitness je:  37
# 446 -ta iteracija, najbolji fitness je:  37
# 447 -ta iteracija, najbolji fitness je:  37
# 448 -ta iteracija, najbolji fitness je:  37
# 449 -ta iteracija, najbolji fitness je:  37
# 450 -ta iteracija, najbolji fitness je:  37
# 451 -ta iteracija, najbolji fitness je:  37
# 452 -ta iteracija, najbolji fitness je:  37
# 453 -ta iteracija, najbolji fitness je:  37
# 454 -ta iteracija, najbolji fitness je:  37
# 455 -ta iteracija, najbolji fitness je:  37
# 456 -ta iteracija, najbolji fitness je:  37
# 457 -ta iteracija, najbolji fitness je:  37
# 458 -ta iteracija, najbolji fitness je:  37
# 459 -ta iteracija, najbolji fitness je:  37
# 460 -ta iteracija, najbolji fitness je:  37
# 461 -ta iteracija, najbolji fitness je:  37
# 462 -ta iteracija, najbolji fitness je:  37
# 463 -ta iteracija, najbolji fitness je:  37
# 464 -ta iteracija, najbolji fitness je:  37
# 465 -ta iteracija, najbolji fitness je:  37
# 466 -ta iteracija, najbolji fitness je:  37
# 467 -ta iteracija, najbolji fitness je:  37
# 468 -ta iteracija, najbolji fitness je:  37
# 469 -ta iteracija, najbolji fitness je:  37
# 470 -ta iteracija, najbolji fitness je:  37
# 471 -ta iteracija, najbolji fitness je:  37
# 472 -ta iteracija, najbolji fitness je:  37
# 473 -ta iteracija, najbolji fitness je:  37
# 474 -ta iteracija, najbolji fitness je:  37
# 475 -ta iteracija, najbolji fitness je:  37
# 476 -ta iteracija, najbolji fitness je:  37
# 477 -ta iteracija, najbolji fitness je:  37
# 478 -ta iteracija, najbolji fitness je:  37
# 479 -ta iteracija, najbolji fitness je:  37
# 480 -ta iteracija, najbolji fitness je:  37
# 481 -ta iteracija, najbolji fitness je:  37
# 482 -ta iteracija, najbolji fitness je:  37
# 483 -ta iteracija, najbolji fitness je:  37
# 484 -ta iteracija, najbolji fitness je:  37
# 485 -ta iteracija, najbolji fitness je:  37
# 486 -ta iteracija, najbolji fitness je:  37
# 487 -ta iteracija, najbolji fitness je:  37
# 488 -ta iteracija, najbolji fitness je:  37
# 489 -ta iteracija, najbolji fitness je:  37
# 490 -ta iteracija, najbolji fitness je:  37
# 491 -ta iteracija, najbolji fitness je:  37
# 492 -ta iteracija, najbolji fitness je:  37
# 493 -ta iteracija, najbolji fitness je:  37
# 494 -ta iteracija, najbolji fitness je:  37
# 495 -ta iteracija, najbolji fitness je:  37
# 496 -ta iteracija, najbolji fitness je:  37
# 497 -ta iteracija, najbolji fitness je:  37
# 498 -ta iteracija, najbolji fitness je:  37
# 499 -ta iteracija, najbolji fitness je:  37
# 500 -ta iteracija, najbolji fitness je:  37
# 501 -ta iteracija, najbolji fitness je:  37
# 502 -ta iteracija, najbolji fitness je:  37
# 503 -ta iteracija, najbolji fitness je:  37
# 504 -ta iteracija, najbolji fitness je:  37
# 505 -ta iteracija, najbolji fitness je:  37
# 506 -ta iteracija, najbolji fitness je:  37
# 507 -ta iteracija, najbolji fitness je:  37
# 508 -ta iteracija, najbolji fitness je:  37
# 509 -ta iteracija, najbolji fitness je:  37
# 510 -ta iteracija, najbolji fitness je:  37
# 511 -ta iteracija, najbolji fitness je:  37
# 512 -ta iteracija, najbolji fitness je:  37
# 513 -ta iteracija, najbolji fitness je:  37
# 514 -ta iteracija, najbolji fitness je:  37
# 515 -ta iteracija, najbolji fitness je:  37
# 516 -ta iteracija, najbolji fitness je:  37
# 517 -ta iteracija, najbolji fitness je:  37
# 518 -ta iteracija, najbolji fitness je:  37
# 519 -ta iteracija, najbolji fitness je:  37
# 520 -ta iteracija, najbolji fitness je:  37
# 521 -ta iteracija, najbolji fitness je:  37
# 522 -ta iteracija, najbolji fitness je:  37
# 523 -ta iteracija, najbolji fitness je:  37
# 524 -ta iteracija, najbolji fitness je:  37
# 525 -ta iteracija, najbolji fitness je:  37
# 526 -ta iteracija, najbolji fitness je:  37
# 527 -ta iteracija, najbolji fitness je:  37
# 528 -ta iteracija, najbolji fitness je:  37
# 529 -ta iteracija, najbolji fitness je:  37
# 530 -ta iteracija, najbolji fitness je:  37
# 531 -ta iteracija, najbolji fitness je:  37
# 532 -ta iteracija, najbolji fitness je:  37
# 533 -ta iteracija, najbolji fitness je:  37
# 534 -ta iteracija, najbolji fitness je:  37
# 535 -ta iteracija, najbolji fitness je:  37
# 536 -ta iteracija, najbolji fitness je:  37
# 537 -ta iteracija, najbolji fitness je:  37
# 538 -ta iteracija, najbolji fitness je:  37
# 539 -ta iteracija, najbolji fitness je:  37
# 540 -ta iteracija, najbolji fitness je:  37
# 541 -ta iteracija, najbolji fitness je:  37
# 542 -ta iteracija, najbolji fitness je:  37
# 543 -ta iteracija, najbolji fitness je:  37
# 544 -ta iteracija, najbolji fitness je:  37
# 545 -ta iteracija, najbolji fitness je:  37
# 546 -ta iteracija, najbolji fitness je:  37
# 547 -ta iteracija, najbolji fitness je:  37
# 548 -ta iteracija, najbolji fitness je:  37
# 549 -ta iteracija, najbolji fitness je:  37
# 550 -ta iteracija, najbolji fitness je:  37
# 551 -ta iteracija, najbolji fitness je:  37
# 552 -ta iteracija, najbolji fitness je:  37
# 553 -ta iteracija, najbolji fitness je:  37
# 554 -ta iteracija, najbolji fitness je:  37
# 555 -ta iteracija, najbolji fitness je:  37
# 556 -ta iteracija, najbolji fitness je:  37
# 557 -ta iteracija, najbolji fitness je:  37
# 558 -ta iteracija, najbolji fitness je:  37
# 559 -ta iteracija, najbolji fitness je:  37
# 560 -ta iteracija, najbolji fitness je:  37
# 561 -ta iteracija, najbolji fitness je:  37
# 562 -ta iteracija, najbolji fitness je:  37
# 563 -ta iteracija, najbolji fitness je:  37
# 564 -ta iteracija, najbolji fitness je:  37
# 565 -ta iteracija, najbolji fitness je:  37
# 566 -ta iteracija, najbolji fitness je:  37
# 567 -ta iteracija, najbolji fitness je:  37
# 568 -ta iteracija, najbolji fitness je:  37
# 569 -ta iteracija, najbolji fitness je:  37
# 570 -ta iteracija, najbolji fitness je:  37
# 571 -ta iteracija, najbolji fitness je:  37
# 572 -ta iteracija, najbolji fitness je:  37
# 573 -ta iteracija, najbolji fitness je:  37
# 574 -ta iteracija, najbolji fitness je:  37
# 575 -ta iteracija, najbolji fitness je:  37
# 576 -ta iteracija, najbolji fitness je:  37
# 577 -ta iteracija, najbolji fitness je:  37
# 578 -ta iteracija, najbolji fitness je:  37
# 579 -ta iteracija, najbolji fitness je:  37
# 580 -ta iteracija, najbolji fitness je:  37
# 581 -ta iteracija, najbolji fitness je:  37
# 582 -ta iteracija, najbolji fitness je:  37
# 583 -ta iteracija, najbolji fitness je:  37
# 584 -ta iteracija, najbolji fitness je:  37
# 585 -ta iteracija, najbolji fitness je:  37
# 586 -ta iteracija, najbolji fitness je:  37
# 587 -ta iteracija, najbolji fitness je:  37
# 588 -ta iteracija, najbolji fitness je:  37
# 589 -ta iteracija, najbolji fitness je:  37
# 590 -ta iteracija, najbolji fitness je:  37
# 591 -ta iteracija, najbolji fitness je:  37
# 592 -ta iteracija, najbolji fitness je:  37
# 593 -ta iteracija, najbolji fitness je:  37
# 594 -ta iteracija, najbolji fitness je:  37
# 595 -ta iteracija, najbolji fitness je:  37
# 596 -ta iteracija, najbolji fitness je:  37
# 597 -ta iteracija, najbolji fitness je:  37
# 598 -ta iteracija, najbolji fitness je:  37
# 599 -ta iteracija, najbolji fitness je:  37
# 600 -ta iteracija, najbolji fitness je:  37
# 601 -ta iteracija, najbolji fitness je:  37
# 602 -ta iteracija, najbolji fitness je:  37
# 603 -ta iteracija, najbolji fitness je:  37
# 604 -ta iteracija, najbolji fitness je:  37
# 605 -ta iteracija, najbolji fitness je:  37
# 606 -ta iteracija, najbolji fitness je:  37
# 607 -ta iteracija, najbolji fitness je:  37
# 608 -ta iteracija, najbolji fitness je:  37
# 609 -ta iteracija, najbolji fitness je:  37
# 610 -ta iteracija, najbolji fitness je:  37
# 611 -ta iteracija, najbolji fitness je:  37
# 612 -ta iteracija, najbolji fitness je:  37
# 613 -ta iteracija, najbolji fitness je:  37
# 614 -ta iteracija, najbolji fitness je:  37
# 615 -ta iteracija, najbolji fitness je:  37
# 616 -ta iteracija, najbolji fitness je:  37
# 617 -ta iteracija, najbolji fitness je:  37
# 618 -ta iteracija, najbolji fitness je:  37
# 619 -ta iteracija, najbolji fitness je:  37
# 620 -ta iteracija, najbolji fitness je:  37
# 621 -ta iteracija, najbolji fitness je:  37
# 622 -ta iteracija, najbolji fitness je:  37
# 623 -ta iteracija, najbolji fitness je:  37
# 624 -ta iteracija, najbolji fitness je:  37
# 625 -ta iteracija, najbolji fitness je:  37
# 626 -ta iteracija, najbolji fitness je:  37
# 627 -ta iteracija, najbolji fitness je:  37
# 628 -ta iteracija, najbolji fitness je:  37
# 629 -ta iteracija, najbolji fitness je:  37
# 630 -ta iteracija, najbolji fitness je:  37
# 631 -ta iteracija, najbolji fitness je:  37
# 632 -ta iteracija, najbolji fitness je:  37
# 633 -ta iteracija, najbolji fitness je:  37
# 634 -ta iteracija, najbolji fitness je:  37
# 635 -ta iteracija, najbolji fitness je:  37
# 636 -ta iteracija, najbolji fitness je:  37
# 637 -ta iteracija, najbolji fitness je:  37
# 638 -ta iteracija, najbolji fitness je:  37
# 639 -ta iteracija, najbolji fitness je:  37
# 640 -ta iteracija, najbolji fitness je:  37
# 641 -ta iteracija, najbolji fitness je:  37
# 642 -ta iteracija, najbolji fitness je:  37
# 643 -ta iteracija, najbolji fitness je:  37
# 644 -ta iteracija, najbolji fitness je:  37
# 645 -ta iteracija, najbolji fitness je:  37
# 646 -ta iteracija, najbolji fitness je:  37
# 647 -ta iteracija, najbolji fitness je:  37
# 648 -ta iteracija, najbolji fitness je:  37
# 649 -ta iteracija, najbolji fitness je:  37
# 650 -ta iteracija, najbolji fitness je:  37
# 651 -ta iteracija, najbolji fitness je:  37
# 652 -ta iteracija, najbolji fitness je:  37
# 653 -ta iteracija, najbolji fitness je:  37
# 654 -ta iteracija, najbolji fitness je:  37
# 655 -ta iteracija, najbolji fitness je:  37
# 656 -ta iteracija, najbolji fitness je:  37
# 657 -ta iteracija, najbolji fitness je:  37
# 658 -ta iteracija, najbolji fitness je:  37
# 659 -ta iteracija, najbolji fitness je:  37
# 660 -ta iteracija, najbolji fitness je:  37
# 661 -ta iteracija, najbolji fitness je:  37
# 662 -ta iteracija, najbolji fitness je:  37
# 663 -ta iteracija, najbolji fitness je:  37
# 664 -ta iteracija, najbolji fitness je:  37
# 665 -ta iteracija, najbolji fitness je:  37
# 666 -ta iteracija, najbolji fitness je:  37
# 667 -ta iteracija, najbolji fitness je:  37
# 668 -ta iteracija, najbolji fitness je:  37
# 669 -ta iteracija, najbolji fitness je:  37
# 670 -ta iteracija, najbolji fitness je:  37
# 671 -ta iteracija, najbolji fitness je:  37
# 672 -ta iteracija, najbolji fitness je:  37
# 673 -ta iteracija, najbolji fitness je:  37
# 674 -ta iteracija, najbolji fitness je:  37
# 675 -ta iteracija, najbolji fitness je:  37
# 676 -ta iteracija, najbolji fitness je:  37
# 677 -ta iteracija, najbolji fitness je:  37
# 678 -ta iteracija, najbolji fitness je:  37
# 679 -ta iteracija, najbolji fitness je:  37
# 680 -ta iteracija, najbolji fitness je:  37
# 681 -ta iteracija, najbolji fitness je:  37
# 682 -ta iteracija, najbolji fitness je:  37
# 683 -ta iteracija, najbolji fitness je:  37
# 684 -ta iteracija, najbolji fitness je:  37
# 685 -ta iteracija, najbolji fitness je:  37
# 686 -ta iteracija, najbolji fitness je:  37
# 687 -ta iteracija, najbolji fitness je:  37
# 688 -ta iteracija, najbolji fitness je:  37
# 689 -ta iteracija, najbolji fitness je:  37
# 690 -ta iteracija, najbolji fitness je:  37
# 691 -ta iteracija, najbolji fitness je:  37
# 692 -ta iteracija, najbolji fitness je:  37
# 693 -ta iteracija, najbolji fitness je:  36
# 694 -ta iteracija, najbolji fitness je:  36
# 695 -ta iteracija, najbolji fitness je:  36
# 696 -ta iteracija, najbolji fitness je:  36
# 697 -ta iteracija, najbolji fitness je:  36
# 698 -ta iteracija, najbolji fitness je:  36
# 699 -ta iteracija, najbolji fitness je:  36
# 700 -ta iteracija, najbolji fitness je:  36
# 701 -ta iteracija, najbolji fitness je:  36
# 702 -ta iteracija, najbolji fitness je:  36
# 703 -ta iteracija, najbolji fitness je:  36
# 704 -ta iteracija, najbolji fitness je:  36
# 705 -ta iteracija, najbolji fitness je:  36
# 706 -ta iteracija, najbolji fitness je:  36
# 707 -ta iteracija, najbolji fitness je:  36
# 708 -ta iteracija, najbolji fitness je:  36
# 709 -ta iteracija, najbolji fitness je:  36
# 710 -ta iteracija, najbolji fitness je:  36
# 711 -ta iteracija, najbolji fitness je:  36
# 712 -ta iteracija, najbolji fitness je:  36
# 713 -ta iteracija, najbolji fitness je:  36
# 714 -ta iteracija, najbolji fitness je:  36
# 715 -ta iteracija, najbolji fitness je:  36
# 716 -ta iteracija, najbolji fitness je:  36
# 717 -ta iteracija, najbolji fitness je:  36
# 718 -ta iteracija, najbolji fitness je:  36
# 719 -ta iteracija, najbolji fitness je:  36
# 720 -ta iteracija, najbolji fitness je:  36
# 721 -ta iteracija, najbolji fitness je:  36
# 722 -ta iteracija, najbolji fitness je:  36
# 723 -ta iteracija, najbolji fitness je:  36
# 724 -ta iteracija, najbolji fitness je:  36
# 725 -ta iteracija, najbolji fitness je:  36
# 726 -ta iteracija, najbolji fitness je:  36
# 727 -ta iteracija, najbolji fitness je:  36
# 728 -ta iteracija, najbolji fitness je:  36
# 729 -ta iteracija, najbolji fitness je:  36
# 730 -ta iteracija, najbolji fitness je:  36
# 731 -ta iteracija, najbolji fitness je:  36
# 732 -ta iteracija, najbolji fitness je:  36
# 733 -ta iteracija, najbolji fitness je:  36
# 734 -ta iteracija, najbolji fitness je:  36
# 735 -ta iteracija, najbolji fitness je:  36
# 736 -ta iteracija, najbolji fitness je:  36
# 737 -ta iteracija, najbolji fitness je:  36
# 738 -ta iteracija, najbolji fitness je:  36
# 739 -ta iteracija, najbolji fitness je:  36
# 740 -ta iteracija, najbolji fitness je:  36
# 741 -ta iteracija, najbolji fitness je:  36
# 742 -ta iteracija, najbolji fitness je:  36
# 743 -ta iteracija, najbolji fitness je:  36
# 744 -ta iteracija, najbolji fitness je:  36
# 745 -ta iteracija, najbolji fitness je:  36
# 746 -ta iteracija, najbolji fitness je:  36
# 747 -ta iteracija, najbolji fitness je:  36
# 748 -ta iteracija, najbolji fitness je:  36
# 749 -ta iteracija, najbolji fitness je:  36
# 750 -ta iteracija, najbolji fitness je:  36
# 751 -ta iteracija, najbolji fitness je:  36
# 752 -ta iteracija, najbolji fitness je:  36
# 753 -ta iteracija, najbolji fitness je:  36
# 754 -ta iteracija, najbolji fitness je:  36
# 755 -ta iteracija, najbolji fitness je:  36
# 756 -ta iteracija, najbolji fitness je:  36
# 757 -ta iteracija, najbolji fitness je:  36
# 758 -ta iteracija, najbolji fitness je:  36
# 759 -ta iteracija, najbolji fitness je:  36
# 760 -ta iteracija, najbolji fitness je:  36
# 761 -ta iteracija, najbolji fitness je:  36
# 762 -ta iteracija, najbolji fitness je:  36
# 763 -ta iteracija, najbolji fitness je:  36
# 764 -ta iteracija, najbolji fitness je:  36
# 765 -ta iteracija, najbolji fitness je:  36
# 766 -ta iteracija, najbolji fitness je:  36
# 767 -ta iteracija, najbolji fitness je:  36
# 768 -ta iteracija, najbolji fitness je:  36
# 769 -ta iteracija, najbolji fitness je:  36
# 770 -ta iteracija, najbolji fitness je:  36
# 771 -ta iteracija, najbolji fitness je:  36
# 772 -ta iteracija, najbolji fitness je:  36
# 773 -ta iteracija, najbolji fitness je:  36
# 774 -ta iteracija, najbolji fitness je:  36
# 775 -ta iteracija, najbolji fitness je:  36
# 776 -ta iteracija, najbolji fitness je:  36
# 777 -ta iteracija, najbolji fitness je:  36
# 778 -ta iteracija, najbolji fitness je:  36
# 779 -ta iteracija, najbolji fitness je:  36
# 780 -ta iteracija, najbolji fitness je:  36
# 781 -ta iteracija, najbolji fitness je:  36
# 782 -ta iteracija, najbolji fitness je:  36
# 783 -ta iteracija, najbolji fitness je:  36
# 784 -ta iteracija, najbolji fitness je:  36
# 785 -ta iteracija, najbolji fitness je:  36
# 786 -ta iteracija, najbolji fitness je:  36
# 787 -ta iteracija, najbolji fitness je:  36
# 788 -ta iteracija, najbolji fitness je:  36
# 789 -ta iteracija, najbolji fitness je:  36
# 790 -ta iteracija, najbolji fitness je:  36
# 791 -ta iteracija, najbolji fitness je:  36
# 792 -ta iteracija, najbolji fitness je:  36
# 793 -ta iteracija, najbolji fitness je:  36
# 794 -ta iteracija, najbolji fitness je:  36
# 795 -ta iteracija, najbolji fitness je:  36
# 796 -ta iteracija, najbolji fitness je:  36
# 797 -ta iteracija, najbolji fitness je:  36
# 798 -ta iteracija, najbolji fitness je:  36
# 799 -ta iteracija, najbolji fitness je:  36
# 800 -ta iteracija, najbolji fitness je:  36
# 801 -ta iteracija, najbolji fitness je:  36
# 802 -ta iteracija, najbolji fitness je:  36
# 803 -ta iteracija, najbolji fitness je:  36
# 804 -ta iteracija, najbolji fitness je:  36
# 805 -ta iteracija, najbolji fitness je:  36
# 806 -ta iteracija, najbolji fitness je:  36
# 807 -ta iteracija, najbolji fitness je:  36
# 808 -ta iteracija, najbolji fitness je:  36
# 809 -ta iteracija, najbolji fitness je:  36
# 810 -ta iteracija, najbolji fitness je:  36
# 811 -ta iteracija, najbolji fitness je:  36
# 812 -ta iteracija, najbolji fitness je:  36
# 813 -ta iteracija, najbolji fitness je:  36
# 814 -ta iteracija, najbolji fitness je:  36
# 815 -ta iteracija, najbolji fitness je:  36
# 816 -ta iteracija, najbolji fitness je:  36
# 817 -ta iteracija, najbolji fitness je:  36
# 818 -ta iteracija, najbolji fitness je:  36
# 819 -ta iteracija, najbolji fitness je:  36
# 820 -ta iteracija, najbolji fitness je:  36
# 821 -ta iteracija, najbolji fitness je:  36
# 822 -ta iteracija, najbolji fitness je:  36
# 823 -ta iteracija, najbolji fitness je:  36
# 824 -ta iteracija, najbolji fitness je:  36
# 825 -ta iteracija, najbolji fitness je:  36
# 826 -ta iteracija, najbolji fitness je:  36
# 827 -ta iteracija, najbolji fitness je:  36
# 828 -ta iteracija, najbolji fitness je:  36
# 829 -ta iteracija, najbolji fitness je:  36
# 830 -ta iteracija, najbolji fitness je:  36
# 831 -ta iteracija, najbolji fitness je:  36
# 832 -ta iteracija, najbolji fitness je:  36
# 833 -ta iteracija, najbolji fitness je:  36
# 834 -ta iteracija, najbolji fitness je:  36
# 835 -ta iteracija, najbolji fitness je:  36
# 836 -ta iteracija, najbolji fitness je:  36
# 837 -ta iteracija, najbolji fitness je:  36
# 838 -ta iteracija, najbolji fitness je:  36
# 839 -ta iteracija, najbolji fitness je:  36
# 840 -ta iteracija, najbolji fitness je:  36
# 841 -ta iteracija, najbolji fitness je:  36
# 842 -ta iteracija, najbolji fitness je:  36
# 843 -ta iteracija, najbolji fitness je:  36
# 844 -ta iteracija, najbolji fitness je:  36
# 845 -ta iteracija, najbolji fitness je:  36
# 846 -ta iteracija, najbolji fitness je:  36
# 847 -ta iteracija, najbolji fitness je:  36
# 848 -ta iteracija, najbolji fitness je:  36
# 849 -ta iteracija, najbolji fitness je:  36
# 850 -ta iteracija, najbolji fitness je:  36
# 851 -ta iteracija, najbolji fitness je:  36
# 852 -ta iteracija, najbolji fitness je:  36
# 853 -ta iteracija, najbolji fitness je:  36
# 854 -ta iteracija, najbolji fitness je:  36
# 855 -ta iteracija, najbolji fitness je:  36
# 856 -ta iteracija, najbolji fitness je:  36
# 857 -ta iteracija, najbolji fitness je:  36
# 858 -ta iteracija, najbolji fitness je:  36
# 859 -ta iteracija, najbolji fitness je:  36
# 860 -ta iteracija, najbolji fitness je:  36
# 861 -ta iteracija, najbolji fitness je:  36
# 862 -ta iteracija, najbolji fitness je:  36
# 863 -ta iteracija, najbolji fitness je:  36
# 864 -ta iteracija, najbolji fitness je:  36
# 865 -ta iteracija, najbolji fitness je:  36
# 866 -ta iteracija, najbolji fitness je:  36
# 867 -ta iteracija, najbolji fitness je:  36
# 868 -ta iteracija, najbolji fitness je:  36
# 869 -ta iteracija, najbolji fitness je:  36
# 870 -ta iteracija, najbolji fitness je:  36
# 871 -ta iteracija, najbolji fitness je:  36
# 872 -ta iteracija, najbolji fitness je:  36
# 873 -ta iteracija, najbolji fitness je:  36
# 874 -ta iteracija, najbolji fitness je:  36
# 875 -ta iteracija, najbolji fitness je:  36
# 876 -ta iteracija, najbolji fitness je:  36
# 877 -ta iteracija, najbolji fitness je:  36
# 878 -ta iteracija, najbolji fitness je:  36
# 879 -ta iteracija, najbolji fitness je:  36
# 880 -ta iteracija, najbolji fitness je:  36
# 881 -ta iteracija, najbolji fitness je:  36
# 882 -ta iteracija, najbolji fitness je:  36
# 883 -ta iteracija, najbolji fitness je:  36
# 884 -ta iteracija, najbolji fitness je:  36
# 885 -ta iteracija, najbolji fitness je:  36
# 886 -ta iteracija, najbolji fitness je:  36
# 887 -ta iteracija, najbolji fitness je:  36
# 888 -ta iteracija, najbolji fitness je:  36
# 889 -ta iteracija, najbolji fitness je:  36
# 890 -ta iteracija, najbolji fitness je:  36
# 891 -ta iteracija, najbolji fitness je:  36
# 892 -ta iteracija, najbolji fitness je:  36
# 893 -ta iteracija, najbolji fitness je:  36
# 894 -ta iteracija, najbolji fitness je:  36
# 895 -ta iteracija, najbolji fitness je:  36
# 896 -ta iteracija, najbolji fitness je:  36
# 897 -ta iteracija, najbolji fitness je:  36
# 898 -ta iteracija, najbolji fitness je:  36
# 899 -ta iteracija, najbolji fitness je:  36
# 900 -ta iteracija, najbolji fitness je:  36
# 901 -ta iteracija, najbolji fitness je:  36
# 902 -ta iteracija, najbolji fitness je:  36
# 903 -ta iteracija, najbolji fitness je:  36
# 904 -ta iteracija, najbolji fitness je:  36
# 905 -ta iteracija, najbolji fitness je:  36
# 906 -ta iteracija, najbolji fitness je:  36
# 907 -ta iteracija, najbolji fitness je:  36
# 908 -ta iteracija, najbolji fitness je:  36
# 909 -ta iteracija, najbolji fitness je:  36
# 910 -ta iteracija, najbolji fitness je:  36
# 911 -ta iteracija, najbolji fitness je:  36
# 912 -ta iteracija, najbolji fitness je:  36
# 913 -ta iteracija, najbolji fitness je:  36
# 914 -ta iteracija, najbolji fitness je:  36
# 915 -ta iteracija, najbolji fitness je:  36
# 916 -ta iteracija, najbolji fitness je:  36
# 917 -ta iteracija, najbolji fitness je:  36
# 918 -ta iteracija, najbolji fitness je:  36
# 919 -ta iteracija, najbolji fitness je:  36
# 920 -ta iteracija, najbolji fitness je:  36
# 921 -ta iteracija, najbolji fitness je:  36
# 922 -ta iteracija, najbolji fitness je:  36
# 923 -ta iteracija, najbolji fitness je:  36
# 924 -ta iteracija, najbolji fitness je:  36
# 925 -ta iteracija, najbolji fitness je:  36
# 926 -ta iteracija, najbolji fitness je:  36
# 927 -ta iteracija, najbolji fitness je:  36
# 928 -ta iteracija, najbolji fitness je:  36
# 929 -ta iteracija, najbolji fitness je:  36
# 930 -ta iteracija, najbolji fitness je:  36
# 931 -ta iteracija, najbolji fitness je:  36
# 932 -ta iteracija, najbolji fitness je:  36
# 933 -ta iteracija, najbolji fitness je:  36
# 934 -ta iteracija, najbolji fitness je:  36
# 935 -ta iteracija, najbolji fitness je:  36
# 936 -ta iteracija, najbolji fitness je:  36
# 937 -ta iteracija, najbolji fitness je:  36
# 938 -ta iteracija, najbolji fitness je:  36
# 939 -ta iteracija, najbolji fitness je:  36
# 940 -ta iteracija, najbolji fitness je:  36
# 941 -ta iteracija, najbolji fitness je:  36
# 942 -ta iteracija, najbolji fitness je:  36
# 943 -ta iteracija, najbolji fitness je:  36
# 944 -ta iteracija, najbolji fitness je:  36
# 945 -ta iteracija, najbolji fitness je:  36
# 946 -ta iteracija, najbolji fitness je:  36
# 947 -ta iteracija, najbolji fitness je:  36
# 948 -ta iteracija, najbolji fitness je:  36
# 949 -ta iteracija, najbolji fitness je:  36
# 950 -ta iteracija, najbolji fitness je:  36
# 951 -ta iteracija, najbolji fitness je:  36
# 952 -ta iteracija, najbolji fitness je:  36
# 953 -ta iteracija, najbolji fitness je:  36
# 954 -ta iteracija, najbolji fitness je:  36
# 955 -ta iteracija, najbolji fitness je:  36
# 956 -ta iteracija, najbolji fitness je:  36
# 957 -ta iteracija, najbolji fitness je:  36
# 958 -ta iteracija, najbolji fitness je:  36
# 959 -ta iteracija, najbolji fitness je:  36
# 960 -ta iteracija, najbolji fitness je:  36
# 961 -ta iteracija, najbolji fitness je:  36
# 962 -ta iteracija, najbolji fitness je:  36
# 963 -ta iteracija, najbolji fitness je:  36
# 964 -ta iteracija, najbolji fitness je:  36
# 965 -ta iteracija, najbolji fitness je:  36
# 966 -ta iteracija, najbolji fitness je:  36
# 967 -ta iteracija, najbolji fitness je:  36
# 968 -ta iteracija, najbolji fitness je:  36
# 969 -ta iteracija, najbolji fitness je:  36
# 970 -ta iteracija, najbolji fitness je:  36
# 971 -ta iteracija, najbolji fitness je:  36
# 972 -ta iteracija, najbolji fitness je:  36
# 973 -ta iteracija, najbolji fitness je:  36
# 974 -ta iteracija, najbolji fitness je:  36
# 975 -ta iteracija, najbolji fitness je:  36
# 976 -ta iteracija, najbolji fitness je:  36
# 977 -ta iteracija, najbolji fitness je:  36
# 978 -ta iteracija, najbolji fitness je:  36
# 979 -ta iteracija, najbolji fitness je:  36
# 980 -ta iteracija, najbolji fitness je:  36
# 981 -ta iteracija, najbolji fitness je:  36
# 982 -ta iteracija, najbolji fitness je:  36
# 983 -ta iteracija, najbolji fitness je:  36
# 984 -ta iteracija, najbolji fitness je:  36
# 985 -ta iteracija, najbolji fitness je:  36
# 986 -ta iteracija, najbolji fitness je:  36
# 987 -ta iteracija, najbolji fitness je:  36
# 988 -ta iteracija, najbolji fitness je:  36
# 989 -ta iteracija, najbolji fitness je:  36
# 990 -ta iteracija, najbolji fitness je:  36
# 991 -ta iteracija, najbolji fitness je:  36
# 992 -ta iteracija, najbolji fitness je:  36
# 993 -ta iteracija, najbolji fitness je:  36
# 994 -ta iteracija, najbolji fitness je:  36
# 995 -ta iteracija, najbolji fitness je:  36
# 996 -ta iteracija, najbolji fitness je:  36
# 997 -ta iteracija, najbolji fitness je:  36
# 998 -ta iteracija, najbolji fitness je:  36
# 999 -ta iteracija, najbolji fitness je:  36
# najbolje resenje je:
# [(4, 0), (28, 0), (26, 0), (29, 1), (15, 1), (45, 1), (46, 1), (10, 1), (18, 1), (44, 1), (6, 2), (49, 2), (22, 2), (25, 2), (14, 2), (47, 2), (37, 2), (7, 3), (39, 3), (24, 3), (9, 3), (38, 3), (0, 3), (20, 4), (23, 4), (30, 4), (8, 4), (11, 4), (17, 4), (34, 4), (3, 4), (41, 5), (48, 5), (40, 5), (19, 5), (31, 5), (32, 5), (1, 6), (35, 6), (36, 6), (13, 6), (21, 6), (12, 6), (27, 6), (42, 7), (16, 7), (2, 7), (33, 8), (5, 8), (43, 8)]
# 36

# %%
population[0].code.sort()

# %%
for i in range(len(population[0].code)):
    print(population[0].code[i], " fitness je = ", population[0].geneFitness(i))
# Out:
# (0, 3)  fitness je =  0
# (1, 6)  fitness je =  3
# (2, 7)  fitness je =  0
# (3, 4)  fitness je =  2
# (4, 0)  fitness je =  0
# (5, 8)  fitness je =  1
# (6, 2)  fitness je =  1
# (7, 3)  fitness je =  0
# (8, 4)  fitness je =  0
# (9, 3)  fitness je =  0
# (10, 1)  fitness je =  0
# (11, 4)  fitness je =  0
# (12, 6)  fitness je =  0
# (13, 6)  fitness je =  1
# (14, 2)  fitness je =  0
# (15, 1)  fitness je =  2
# (16, 7)  fitness je =  2
# (17, 4)  fitness je =  0
# (18, 1)  fitness je =  0
# (19, 5)  fitness je =  0
# (20, 4)  fitness je =  1
# (21, 6)  fitness je =  2
# (22, 2)  fitness je =  2
# (23, 4)  fitness je =  0
# (24, 3)  fitness je =  0
# (25, 2)  fitness je =  1
# (26, 0)  fitness je =  0
# (27, 6)  fitness je =  3
# (28, 0)  fitness je =  0
# (29, 1)  fitness je =  1
# (30, 4)  fitness je =  3
# (31, 5)  fitness je =  0
# (32, 5)  fitness je =  0
# (33, 8)  fitness je =  0
# (34, 4)  fitness je =  2
# (35, 6)  fitness je =  1
# (36, 6)  fitness je =  1
# (37, 2)  fitness je =  0
# (38, 3)  fitness je =  0
# (39, 3)  fitness je =  0
# (40, 5)  fitness je =  1
# (41, 5)  fitness je =  0
# (42, 7)  fitness je =  0
# (43, 8)  fitness je =  0
# (44, 1)  fitness je =  3
# (45, 1)  fitness je =  0
# (46, 1)  fitness je =  1
# (47, 2)  fitness je =  1
# (48, 5)  fitness je =  1
# (49, 2)  fitness je =  0

# %%
brStudenata = len(zeljeStudenata)
brMentora = len(mentoriZauzetost)
mentoriKapacitet = sum(mentoriZauzetost)

# %%
# !pip install python-constraint
# Out:
# Requirement already satisfied: python-constraint in c:\users\teodo\anaconda3\lib\site-packages (1.4.0)

# %%
import constraint
mapirajMentore = {}
br=0
for i in range(len(mentoriZauzetost)):
    for j in range(mentoriZauzetost[i]):
        
        mapirajMentore[br] = i
        br += 1

# %%
problem = constraint.Problem()

# %%
# npr niz[i]=j oznacava da je mentoru mapirajMentore[i] dodeljen j-ti student
problem.addVariables(['mentor_{}'.format(i) for i in range(min(mentoriKapacitet, brStudenata))], range(brStudenata))
problem.addConstraint(constraint.AllDifferentConstraint())

# %%
solutions = problem.getSolutions()

# %%
min_val = brStudenata*brMentora
najbolje_resenje = None

for sol in range solutions:
    val = 0
    for example in sol:
    
        ment = int(example.strip('mentor_'))
        print('student {} = {}'.format(sol[example], zeljeStudenata[int(sol[example])][mapirajMentore[ment]]))
        val += zeljeStudenata[int(sol[example])][mapirajMentore[ment]]
    if min_val>val:
        min_val = val
        najbolje_resenje = sol

# %%
print(val)
